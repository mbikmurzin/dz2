# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
data_hh_ru = pd.read_csv("data/dst-3.0_16_1_hh_database.csv", sep=";")

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
data_hh_ru.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
data_hh_ru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
unique_skill = data_hh_ru["Опыт работы"].nunique()
print("Количество уникальных значений:", unique_skill)

most_post = data_hh_ru["Ищет работу на должность:"].mode()[0]
print("Самая распространненая из искомых должностей:", most_post)
# Out:
# Количество уникальных значений: 44413
# Самая распространненая из искомых должностей: Системный администратор

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
import pandas as pd

# Создаем функцию для извлечения уровня образования
def extract_education_level(education):
    level = ' '.join(education.split()[:3])  # Берем первые три слова
    # Сопоставляем полученную строку с нужными категориями
    if 'Высшее' in level:
        return 'высшее'
    elif 'Неоконченное' in level:
        return 'неоконченное высшее'
    elif 'Среднее специальное' in level:
        return 'среднее специальное'
    elif 'Среднее' in level:
        return 'среднее'
    else:
        return None  # На случай, если попадется неизвестная категория

# Применяем функцию к столбцу "Образование и ВУЗ" и создаем новый столбец "Образование"
data_hh_ru['Образование'] = data_hh_ru['Образование и ВУЗ'].apply(lambda x: extract_education_level(x))

# Проверяем уникальные значения в новом столбце
print(data_hh_ru['Образование'].unique())

# Удаляем исходный столбец "Образование и ВУЗ"
data_hh_ru = data_hh_ru.drop(columns=['Образование и ВУЗ'])

# Подсчет количества соискателей со средним образованием
count_middle_education = data_hh_ru[data_hh_ru['Образование'] == 'среднее'].shape[0]

print("Количество соискателей со средним образованием:", count_middle_education)
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# Количество соискателей со средним образованием: 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Разделяем столбец "Пол, возраст" на три части
data_hh_ru[['Пол', 'Возраст', 'Дата рождения']] = data_hh_ru['Пол, возраст'].str.split(' , ', expand=True)

# Преобразуем пол в формат "М" и "Ж"
data_hh_ru['Пол'] = data_hh_ru['Пол'].apply(lambda x: 'М' if 'Мужчина' in x else 'Ж')

# Извлекаем числовое значение возраста и преобразуем его в целое число
data_hh_ru['Возраст'] = data_hh_ru['Возраст'].str.extract('(\d+)').astype(int)

# Удаляем исходный столбец "Пол, возраст"
data_hh_ru = data_hh_ru.drop(columns=['Пол, возраст', 'Дата рождения'])

# Расчет: Сколько процентов женских резюме представлено в данных?
female_percentage = round((data_hh_ru['Пол'].value_counts(normalize=True)['Ж'] * 100), 2)
print("Процент женских резюме:", female_percentage)

# Расчет: Средний возраст соискателей
average_age = round(data_hh_ru['Возраст'].mean(), 1)
print("Средний возраст соискателей:", average_age)
# Out:
# Процент женских резюме: 19.07
# Средний возраст соискателей: 32.2
# <>:8: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# <>:8: SyntaxWarning:
#
# invalid escape sequence '\d'
#
# C:\Users\Пользватель\AppData\Local\Temp\ipykernel_16724\2684299234.py:8: SyntaxWarning:
#
# invalid escape sequence '\d'

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def get_experience(arg):
    if arg is np.nan or arg == 'Не указано':
        return None
    year_words=['год', 'года', 'лет']
    month_words=['месяц', 'месяца', 'месяцев']
    arg_splitted = arg.split(' ')[:7]
    years = 0
    months = 0
    for index, item in enumerate (arg_splitted):
        if item in year_words:
            years = int(arg_splitted[index-1])
        if item in month_words:
            months = int(arg_splitted[index-1])
    return int(years*12 + months)
data_hh_ru['Опыт работы (месяц)'] = data_hh_ru['Опыт работы'].apply(get_experience)
#data = data.drop('Опыт работы', axis=1)
print(round(data_hh_ru['Опыт работы (месяц)'].median()))
# Out:
# 100

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск',
                  'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 
                  'Воронеж', 'Волгоград']

# Функция для преобразования признака "Город, переезд, командировки"
def parse_city_relocation_travel(arg):
    # Проверка на пропуски
    if pd.isna(arg):
        return pd.Series([np.nan, False, False])
    
    # Разделение строки на части
    parts = [p.strip() for p in arg.split(',')]

    # Извлечение города
    city = parts[0]
    if city in ['Москва', 'Санкт-Петербург']:
        city = city
    elif city in million_cities:
        city = 'город-миллионник'
    else:
        city = 'другие'

    # Извлечение готовности к переезду
    relocation = any(keyword in arg for keyword in ['готов к переезду', 'хочу переехать'])

    # Извлечение готовности к командировкам
    travel = any(keyword in arg for keyword in ['готов к командировкам', 'готова к командировкам'])
    
    return pd.Series([city, relocation, travel])

# Применяем функцию и создаем новые столбцы
data_hh_ru[['Город', 'Готовность к переезду', 'Готовность к командировкам']] = data_hh_ru['Город, переезд, командировки'].apply(parse_city_relocation_travel)

# Удаляем исходный столбец "Город, переезд, командировки"
data_hh_ru = data_hh_ru.drop(columns=['Город, переезд, командировки'])

# Расчет: Сколько процентов соискателей живут в Санкт-Петербурге?
spb_percentage = round((data_hh_ru['Город'].value_counts(normalize=True).get('Санкт-Петербург', 0) * 100))
print("Процент соискателей, живущих в Санкт-Петербурге:", spb_percentage)

# Расчет: Сколько процентов соискателей готовы к переезду и командировкам?
print(round(data_hh_ru[
    data_hh_ru['Готовность к переезду'] & data_hh_ru['Готовность к командировкам']
].shape[0] / data_hh_ru.shape[0] *100))
# Out:
# Процент соискателей, живущих в Санкт-Петербурге: 11
# 62

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Возможные категории для One Hot Encoding
employment_types = ['полная занятость', 'частичная занятость', 'проектная работа', 'стажировка', 'волонтерство']
schedule_types = ['полный день', 'сменный график', 'гибкий график', 'удалённая работа', 'вахтовый метод']

# Создаем "мигалки" для каждой категории в "Занятость"
for employment in employment_types:
    data_hh_ru[employment] = data_hh_ru['Занятость'].apply(lambda x: employment in x)

# Создаем "мигалки" для каждой категории в "График"
for schedule in schedule_types:
    data_hh_ru[schedule] = data_hh_ru['График'].apply(lambda x: schedule in x)

# Удаляем исходные столбцы "Занятость" и "График"
data_hh_ru = data_hh_ru.drop(columns=['Занятость', 'График'])

# Расчет: Сколько людей ищут проектную работу и волонтерство
project_and_volunteer_count = data_hh_ru[(data_hh_ru['проектная работа'] == True) & (data_hh_ru['волонтерство'] == True)].shape[0]
print("Количество людей, ищущих проектную работу и волонтерство:", project_and_volunteer_count)

# Расчет: Сколько людей хотят работать вахтовым методом и с гибким графиком
shift_and_flexible_count = data_hh_ru[(data_hh_ru['вахтовый метод'] == True) & (data_hh_ru['гибкий график'] == True)].shape[0]
print("Количество людей, ищущих работу вахтовым методом и с гибким графиком:", shift_and_flexible_count)
# Out:
# Количество людей, ищущих проектную работу и волонтерство: 436
# Количество людей, ищущих работу вахтовым методом и с гибким графиком: 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
def get_salary_num(arg):
    salary =float(arg.split(' ')[0])
    return salary

def get_salary_currency(arg):
    currency_dict = {
        'USD': 'USD', 'KZT': 'KZT',
        'грн': 'UAH', 'белруб': 'BYN',
        'EUR': 'EUR', 'KGS': 'KGS',
        'сум': 'UZS', 'AZN': 'AZN'
    }
    curr = arg.split(' ')[1].replace('.', '')
    if curr == 'руб':
        return 'RUB'
    else:
        return currency_dict[curr]
    
rates = pd.read_csv('data/ExchangeRates.csv')
rates['date'] = pd.to_datetime(rates['date'], dayfirst=True).dt.date
data_hh_ru['Обновление резюме'] = pd.to_datetime(data_hh_ru['Обновление резюме'], dayfirst=True).dt.date
data_hh_ru['ЗП (tmp)'] = data_hh_ru['ЗП'].apply(get_salary_num)
data_hh_ru['Курс (tmp)'] = data_hh_ru['ЗП'].apply(get_salary_currency)
merged = data_hh_ru.merge(
    rates, 
    left_on=['Курс (tmp)', 'Обновление резюме'],
    right_on=['currency', 'date',], 
    how='left'
)
merged['close'] = merged['close'].fillna(1)
merged['proportion'] = merged['proportion'].fillna(1)
data_hh_ru['ЗП (руб)'] = merged['close'] * merged['ЗП (tmp)'] / merged['proportion']
data_hh_ru = data_hh_ru.drop(['ЗП', 'ЗП (tmp)', 'Курс (tmp)'], axis=1)
print(round(data_hh_ru['ЗП (руб)'].median()/1000))
# Out:
# C:\Users\Пользватель\AppData\Local\Temp\ipykernel_16724\1873961936.py:19: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 59

# %%
data_hh_ru.drop("Опыт работы", axis=1, inplace=True)
data_hh_ru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int32
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
import pandas as pd
import matplotlib.pyplot as plt


# 1. Построение гистограммы с помощью matplotlib
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(data_hh_ru['Возраст'], bins=15, color='skyblue', edgecolor='black')
plt.xlabel('Возраст')
plt.ylabel('Количество соискателей')
plt.title('Распределение возраста соискателей')

# 2. Построение коробчатой диаграммы (boxplot)
plt.subplot(1, 2, 2)
plt.boxplot(data_hh_ru['Возраст'], vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.xlabel('Возраст')
plt.title('Коробчатая диаграмма возраста соискателей')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Мода распределения:
# Мода — это наиболее частое значение в данных. На гистограмме видно, что пик приходится на возраст примерно 25-30 лет. Это значит, что большинство соискателей находятся в этом возрастном диапазоне.
#
# ## Предельные значения:
# На гистограмме видно, что возраст соискателей варьируется примерно от 18 до чуть более 80 лет.
# Коробчатая диаграмма подтверждает, что основной диапазон возраста находится между 20 и 45 годами.
#
# ## Интервал, в котором находится большинство соискателей:
# Большинство соискателей находятся в интервале от 20 до 40 лет. Это видно из гистограммы и подтверждается коробчатой диаграммой.
#
# ## Аномалии:
# Коробчатая диаграмма показывает точки справа от "усиков" — это значения, которые можно считать выбросами или аномалиями. Например, возраст более 60-65 лет выходит за пределы основного диапазона и может рассматриваться как аномальный.
# На графике также виден единичный случай около 100 лет, что может быть ошибкой или редким исключением.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = px.histogram(
    data_frame=data_hh_ru,
    x='Опыт работы (месяц)',
    title='Распределение опыта работы соискателей',
    histnorm='percent',
    width=500,
    marginal='box',
)
fig.show()

# %% [markdown]
# ## Мода распределения:
# Пик распределения находится около 0–100 месяцев, что говорит о том, что большинство соискателей имеют относительно небольшой опыт работы (менее 8 лет).
#
# ## Предельные значения:
# Минимальное значение — 0 месяцев (некоторые соискатели не имеют опыта работы).
# Максимальные значения находятся за пределами 1000 месяцев (около 83 лет), что является экстремально высоким и явно аномальным значением для данных о трудовом стаже.
#
# ## Интервал, в котором находится большинство значений:
# Большая часть данных сосредоточена в диапазоне до 200 месяцев (около 16,5 лет), что подтверждается гистограммой.
# Коробчатая диаграмма также показывает, что значения до примерно 200–250 месяцев укладываются в основной интервал распределения (межквартильный размах).
#
# ## Аномалии:
# Опыт работы свыше 300 месяцев (около 25 лет) можно считать аномалией, поскольку такие значения редко встречаются и выходят за пределы "усиков" коробчатой диаграммы.
# На графике видно несколько точек, значительно превышающих это значение, вплоть до максимального выброса около 1000 месяцев.
#
# ## Выводы
# Большинство соискателей имеют стаж до 16 лет, и значительные выбросы наблюдаются за пределами 25 лет опыта.
# Значения свыше 300 месяцев могут считаться аномальными, так как они выбиваются из общего диапазона.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = px.histogram(
    data_frame=data_hh_ru,
    x='ЗП (руб)',
    title='Распределение опыта работы соискателей',
    histnorm='percent',
    width=500,
    marginal='box',
)
fig.show()

# %% [markdown]
# ## Мода распределения:
# Большая часть соискателей указала заработную плату, близкую к началу оси, вероятно, в диапазоне от 0 до 100 тысяч рублей. На этом графике сложно точно определить моду, так как значения на оси x из-за выбросов сильно сжаты.
#
# ## Предельные значения:
# Минимальные значения заработной платы близки к нулю.
# Максимальные значения достигают 20 миллионов рублей, что является очень высоким значением и может быть аномалией или ошибкой в данных.
#
# ## Интервал, в котором находится большинство значений:
# На основании плотности гистограммы можно предположить, что большинство значений заработной платы находятся в диапазоне до 100-200 тысяч рублей, так как плотность данных резко падает после этого значения.
#
# ## Аномалии:
# Значения заработной платы, превышающие 1 миллион рублей, можно считать аномальными, поскольку они сильно выбиваются из основного распределения.
# Выбросы вплоть до 20 миллионов рублей указывают на редкие случаи, которые могут быть ошибочными или относиться к руководящим позициям в крупных компаниях, но такие значения все равно считаются необычными для большинства данных.
#
# ## Выводы
# Большинство соискателей ожидает заработную плату до 200 тысяч рублей.
# Значения выше 1 миллиона рублей — редкость и могут быть классифицированы как выбросы.
# Значения, превышающие 10 миллионов рублей, скорее всего, являются ошибками ввода или специфическими случаями.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Оставляем только данные с зарплатой менее 1 млн рублей
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Группируем данные по уровню образования и рассчитываем медианную зарплату
median_salary_by_education = filtered_data.groupby('Образование')['ЗП (руб)'].median().sort_values()

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
median_salary_by_education.plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная заработная плата (руб)')
plt.title('Медианная заработная плата по уровню образования')
plt.show()

# %% [markdown]
# ## Наибольшая медианная заработная плата:
# Соискатели с высшим образованием ожидают наибольшую медианную зарплату среди всех категорий. Это подтверждает, что более высокий уровень образования связан с более высокими ожиданиями по заработной плате.
#
# ## Наименьшая медианная заработная плата:
# Наименьшая медианная зарплата наблюдается у соискателей со средним образованием. Это может быть связано с ограниченными возможностями для высокооплачиваемой работы при отсутствии профессионального или высшего образования.
#
# ## Зависимость заработной платы от уровня образования:
# Из диаграммы видно, что уровень образования оказывает влияние на ожидаемую заработную плату. Медианная зарплата возрастает с увеличением уровня образования: от среднего до высшего.
#
# ## Заключение
# Признак уровня образования действительно может быть важным для прогнозирования заработной платы, так как существует положительная корреляция между уровнем образования и желаемой зарплатой. Соискатели с более высоким уровнем образования имеют более высокие ожидания по заработной плате, что отражает востребованность и ценность квалифицированного труда на рынке.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Оставляем только данные с зарплатой менее 1 млн рублей
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Группируем данные по уровню образования и рассчитываем медианную зарплату
median_salary_by_education = filtered_data.groupby('Город')['ЗП (руб)'].median().sort_values()

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
median_salary_by_education.plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel('Город')
plt.ylabel('Медианная заработная плата (руб)')
plt.title('Медианная заработная плата в зависимости от города')
plt.show()

# %% [markdown]
# ## Наибольшая медианная заработная плата:
# Соискатели из Москвы имеют самую высокую медианную зарплату среди всех категорий городов. Это ожидаемо, так как Москва является столицей с высокой стоимостью жизни и большим количеством высокооплачиваемых позиций.
#
# ## Средняя медианная заработная плата:
# Санкт-Петербург также показывает сравнительно высокие медианные значения заработной платы, но несколько ниже, чем в Москве. Это объясняется тем, что Санкт-Петербург — второй по значимости город России с относительно высоким уровнем зарплат.
#
# ## Наименьшая медианная заработная плата:
# Группы «город-миллионник» и «другие» имеют самые низкие медианные зарплаты. В городах-миллионниках и других менее крупных городах заработные платы, как правило, ниже, чем в Москве и Санкт-Петербурге.
#
# ## Зависимость заработной платы от города:
# Диаграмма показывает, что город проживания оказывает значительное влияние на ожидаемую заработную плату. В Москве и Санкт-Петербурге медианные зарплаты выше, чем в городах-миллионниках и других населённых пунктах.
#
# ## Заключение
# Признак города может быть важным для прогнозирования заработной платы, так как он отражает различия в уровне оплаты труда в зависимости от региона.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Фильтруем данные, чтобы исключить аномалии
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Группируем данные и рассчитываем медианную зарплату по категориям "Готовность к переезду" и "Готовность к командировкам"
median_salary = filtered_data.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()

# Построение многоуровневой столбчатой диаграммы
median_salary.plot(kind='bar', stacked=False, color=['skyblue', 'salmon'], edgecolor='black', figsize=(10, 6))
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб)')
plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.legend(title='Готовность к командировкам', labels=['Не готов', 'Готов'])
plt.show()

# %% [markdown]
# ## Готовность к переезду:
# Соискатели, которые готовы к переезду, в среднем ожидают более высокую медианную заработную плату, чем те, кто не готов переехать. Это может свидетельствовать о том, что соискатели, готовые к переезду, рассчитывают на более высокооплачиваемые позиции, возможно, в других регионах или странах, где заработные платы могут быть выше.
#
# ## Готовность к командировкам:
# Интересно, что готовность к командировкам, наоборот, связана с меньшей медианной заработной платой по сравнению с теми, кто не готов к командировкам. Это может быть связано с тем, что кандидаты, не готовые к командировкам, могут претендовать на более высокооплачиваемые позиции, предполагающие меньше поездок.
#
# ## Сравнение категорий:
# В категории "Готов к переезду и командировкам" и "Не готов к переезду, но готов к командировкам" медианные зарплаты ниже по сравнению с остальными. Это может говорить о том, что гибкость по переезду не всегда подразумевает более высокую оплату, если речь идет о позициях с частыми командировками.
#
# ## Зависимость между готовностью и зарплатой:
# Общий тренд подтверждает, что готовность к переезду может быть связана с более высокими ожиданиями по заработной плате, особенно если работа не связана с частыми командировками.
#
# ## Заключение
# Признаки готовности к переезду и готовности к командировкам действительно оказывают влияние на ожидаемую заработную плату. Готовность к переезду часто сопровождается более высокими зарплатными ожиданиями, тогда как готовность к командировкам может, напротив, коррелировать с более низкими зарплатными ожиданиями.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Фильтруем данные, чтобы исключить выбросы (зарплата менее 1 млн)
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Создаем сводную таблицу, вычисляя медианную заработную плату в каждой группе
pivot_table = filtered_data.pivot_table(
    values='ЗП (руб)', 
    index='Возраст', 
    columns='Образование', 
    aggfunc='median'
)

# Построение тепловой карты
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="YlGnBu", cbar_kws={'label': 'Медианная зарплата (руб)'})
plt.title('Тепловая карта медианной заработной платы в зависимости от возраста и образования')
plt.xlabel('Образование')
plt.ylabel('Возраст')
plt.show()

# %% [markdown]
# ## Возраст и высшее образование:
# Соискатели с высшим образованием, особенно в возрасте от 30 до 50 лет, имеют более высокие медианные значения заработной платы по сравнению с другими группами. Эти данные предполагают, что высокий уровень образования и значительный трудовой опыт (представленный возрастом) положительно влияют на зарплатные ожидания.
#
# ## Наименьшие медианные зарплаты:
# Наиболее низкие зарплатные ожидания наблюдаются у молодых соискателей (до 20 лет) со средним и средним специальным образованием. Это может быть связано с отсутствием опыта и низкими квалификационными требованиями к начальным позициям.
#
# ## Влияние уровня образования:
# Высшее образование связано с более высокими зарплатными ожиданиями практически в каждой возрастной группе. Соискатели с неоконченным высшим образованием также имеют умеренные ожидания, но немного ниже, чем соискатели с полным высшим образованием.
# Соискатели со средним и средним специальным образованием, как правило, ожидают более низкие зарплаты, независимо от возраста, что говорит о важности уровня образования при прогнозировании зарплатных ожиданий.
#
# ## Возрастные группы:
# В возрастной группе старше 60 лет наблюдается снижение медианных зарплатных ожиданий для всех уровней образования. Это может быть связано с тем, что многие люди в этом возрасте рассматривают неполную занятость или менее высокооплачиваемую работу.
#
# ## Заключение
# Тепловая карта наглядно демонстрирует, что уровень образования и возраст играют важную роль в определении ожидаемой заработной платы. Высшее образование, в особенности для соискателей в возрасте от 30 до 50 лет, связано с более высокими зарплатными ожиданиями. Это подтверждает, что признаки "Возраст" и "Образование" являются важными при прогнозировании заработной платы.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Перевод опыта работы из месяцев в годы
data_hh_ru['Опыт работы (год)'] = data_hh_ru['Опыт работы (месяц)'] / 12

# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(data_hh_ru['Возраст'], data_hh_ru['Опыт работы (год)'], color='skyblue', edgecolor='black', label='Соискатели')

# Добавление линии, где опыт работы равен возрасту
plt.plot([0, 100], [0, 100], color='red', linestyle='--', label='Опыт работы = Возраст')

# Настройка осей и заголовков
plt.xlabel('Возраст (лет)')
plt.ylabel('Опыт работы (лет)')
plt.title('Зависимость опыта работы от возраста')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Основное распределение:
# Большинство точек на графике располагается ниже красной пунктирной линии, что логично, поскольку опыт работы обычно составляет часть жизни человека, а не равен его возрасту.
# С увеличением возраста мы наблюдаем увеличение опыта работы, что соответствует нормальной тенденции.
#
# ## Аномалии:
# Точки, лежащие на красной линии или выше нее, представляют аномалии, где опыт работы равен или даже превышает возраст. Это невозможно, так как человеку требуются годы для обучения и развития до начала трудовой деятельности.
# Такие аномальные значения могут быть следствием ошибок в данных (например, неправильно указанный опыт работы или возраст), и их следует дополнительно проверить и, возможно, очистить из данных.
#
# ## Тенденции:
# Видно, что с увеличением возраста разброс опыта работы увеличивается, что может отражать различия в карьерных траекториях и периодах трудовой активности у соискателей.
# У людей в возрасте 20-40 лет опыт работы чаще всего составляет менее половины их возраста, что соответствует обычному началу карьеры после завершения учебы.
#
# ## Заключение
# Прямая на графике (опыт работы = возраст) помогает нам легко выявить аномалии. Эти аномальные значения стоит исследовать и, возможно, удалить или скорректировать, так как они могут искажать анализ и последующие прогнозы.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Фильтруем данные (исключаем выбросы)
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Создаем словарь для хранения медианной зарплаты для каждого типа занятости
median_salaries = {
    'полная занятость': filtered_data[filtered_data['полная занятость']]['ЗП (руб)'].median(),
    'частичная занятость': filtered_data[filtered_data['частичная занятость']]['ЗП (руб)'].median(),
    'проектная работа': filtered_data[filtered_data['проектная работа']]['ЗП (руб)'].median(),
    'стажировка': filtered_data[filtered_data['стажировка']]['ЗП (руб)'].median(),
    'волонтерство': filtered_data[filtered_data['волонтерство']]['ЗП (руб)'].median(),
}

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
plt.bar(median_salaries.keys(), median_salaries.values(), color=['skyblue', 'lightgreen', 'salmon', 'gold', 'purple'])
plt.xlabel("Тип занятости")
plt.ylabel("Медианная заработная плата (руб)")
plt.title("Медианная заработная плата в зависимости от типа занятости")
plt.show()

# %% [markdown]
# ## Полная занятость и проектная работа:
# Соискатели, ищущие полную занятость и проектную работу, ожидают наиболее высокую медианную заработную плату среди всех категорий. Это неудивительно, так как полная занятость обычно подразумевает основное место работы с полным рабочим днем, а проектная работа может включать высококвалифицированные проекты, требующие особых навыков.
#
# ## Частичная занятость:
# Соискатели, заинтересованные в частичной занятости, имеют медианные зарплатные ожидания ниже, чем те, кто ищет полную занятость или проектные работы, но выше, чем те, кто ищет стажировки или волонтерство.
#
# ## Стажировка и волонтерство:
# Самые низкие зарплатные ожидания наблюдаются среди соискателей, заинтересованных в стажировках и волонтерстве. Это вполне ожидаемо, так как стажировки часто предполагают получение опыта работы без значительных финансовых ожиданий, а волонтерство, как правило, не является оплачиваемой работой или имеет минимальную оплату.
#
# ## Заключение:
# Тип занятости оказывает значительное влияние на ожидаемую заработную плату. Соискатели, заинтересованные в полной занятости и проектной работе, ожидают более высокую заработную плату, тогда как те, кто ищет стажировки и волонтерство, обычно имеют более низкие зарплатные ожидания.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Фильтрация данных (исключаем выбросы)
filtered_data = data_hh_ru[data_hh_ru['ЗП (руб)'] < 1000000]

# Создание словаря для медианной зарплаты для каждого формата работы
median_salaries_format = {
    'полный день': filtered_data[filtered_data['полный день']]['ЗП (руб)'].median(),
    'сменный график': filtered_data[filtered_data['сменный график']]['ЗП (руб)'].median(),
    'гибкий график': filtered_data[filtered_data['гибкий график']]['ЗП (руб)'].median(),
    'удалённая работа': filtered_data[filtered_data['удалённая работа']]['ЗП (руб)'].median(),
    'вахтовый метод': filtered_data[filtered_data['вахтовый метод']]['ЗП (руб)'].median(),
}

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
plt.bar(median_salaries_format.keys(), median_salaries_format.values(), color=['skyblue', 'lightgreen', 'salmon', 'gold', 'purple'])
plt.xlabel("Формат работы")
plt.ylabel("Медианная заработная плата (руб)")
plt.title("Медианная заработная плата в зависимости от формата работы")
plt.show()

# %% [markdown]
# ## Полный день:
# Соискатели, предпочитающие полный рабочий день, имеют самые высокие медианные зарплатные ожидания среди всех форматов работы. Это соответствует ожиданиям, так как полный рабочий день чаще всего предполагает основное место работы с полноценной оплатой.
#
# ## Гибкий график:
# Соискатели, заинтересованные в гибком графике, также ожидают относительно высокие зарплаты, что может объясняться тем, что гибкость часто ценится специалистами высокого уровня, которым важен баланс между работой и личной жизнью.
#
# ## Сменный график:
# Соискатели, предпочитающие сменный график, ожидают более низкую медианную заработную плату по сравнению с форматом полного дня или гибкого графика. Это может быть связано с тем, что сменный график встречается в ряде отраслей, где зарплаты ниже среднего уровня, таких как розничная торговля или обслуживание.
#
# ## Вахтовый метод:
# Вахтовый метод также предполагает умеренные ожидания по зарплате. Вахтовая работа часто включает компенсации за условия раб

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Подсчет полных дубликатов
duplicate_count = data_hh_ru.duplicated().sum()

# Удаление полных дубликатов
data_hh_ru = data_hh_ru.drop_duplicates()

# Вывод количества полных дубликатов
print("Количество полных копий:", duplicate_count)
# Out:
# Количество полных копий: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Вывод информации о числе пропусков в каждом столбце
missing_values = data_hh_ru.isnull().sum()

# Вывод результатов
print("Число пропусков в каждом столбце:")
print(missing_values)

# Число пропусков в столбце «Опыт работы (месяц)»
missing_experience = missing_values['Опыт работы (месяц)']
print("\nКоличество пропусков в столбце «Опыт работы (месяц)»:", missing_experience)
# Out:
# Число пропусков в каждом столбце:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# частичная занятость                  0
# проектная работа                     0
# стажировка                           0
# волонтерство                         0
# полный день                          0
# сменный график                       0
# гибкий график                        0
# удалённая работа                     0
# вахтовый метод                       0
# ЗП (руб)                             0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаление строк с пропусками в столбцах «Последнее/нынешнее место работы» и «Последняя/нынешняя должность»
data_hh_ru = data_hh_ru.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполнение пропусков в столбце «Опыт работы (месяц)» медианным значением
median_experience = data_hh_ru['Опыт работы (месяц)'].median()
data_hh_ru['Опыт работы (месяц)'].fillna(median_experience, inplace=True)

# Вычисление среднего значения в столбце «Опыт работы (месяц)» после заполнения пропусков
mean_experience = data_hh_ru['Опыт работы (месяц)'].mean()

# Вывод среднего значения, округленного до целых
print("Результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков:", round(mean_experience))
# Out:
# Результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков: 114
# C:\Users\Пользватель\AppData\Local\Temp\ipykernel_16724\434579934.py:6: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Подсчет количества выбросов (зарплата менее 1,000 или более 1,000,000 рублей)
outliers = data_hh_ru[(data_hh_ru['ЗП (руб)'] < 1000) | (data_hh_ru['ЗП (руб)'] > 1000000)]
outliers_count = outliers.shape[0]

# Удаление выбросов из данных
data_hh_ru = data_hh_ru[(data_hh_ru['ЗП (руб)'] >= 1000) & (data_hh_ru['ЗП (руб)'] <= 1000000)]

# Вывод количества выбросов
print("Количество выбросов, найденных и удаленных:", outliers_count)
# Out:
# Количество выбросов, найденных и удаленных: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Находим строки, где опыт работы в годах больше или равен возрасту
outliers_experience = data_hh_ru[data_hh_ru['Опыт работы (месяц)'] / 12 >= data_hh_ru['Возраст']]
outliers_experience_count = outliers_experience.shape[0]

# Удаляем такие строки из данных
data_hh_ru = data_hh_ru[data_hh_ru['Опыт работы (месяц)'] / 12 < data_hh_ru['Возраст']]

# Вывод количества найденных и удаленных выбросов
print("Количество выбросов, найденных и удаленных (опыт работы превышает возраст):", outliers_experience_count)
# Out:
# Количество выбросов, найденных и удаленных (опыт работы превышает возраст): 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(data_hh_ru['Возраст'] + 1)
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 4 *log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 *log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Log Age Distribution');

def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned
outliers, cleaned_data = outliers_z_score_mod(data_hh_ru, 'Возраст', left=3,  right=4, log_scale=True)
print(outliers.shape[0])
# Out:
# 3

# %% [markdown]
# ваш коммментарий здесь
